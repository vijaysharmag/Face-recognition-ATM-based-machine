# %%
import cv2
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
cap = cv2.VideoCapture(0)
while True:
    _, img = cap.read()
# image = cv2.imread("test1.png")
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
 
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    print (faces)
    #print (faces.shape)
    print ("Number of faces detected: ")
    for (x, y, w , h) in faces:
        cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0 , 0), 2)
    cv2.rectangle(img, ((0,img.shape[0] -25)),(270, img.shape[0]), (255,255,255), -1)
    cv2.putText(img, "Number of faces detected: " + str(img.shape[0]), (0,img.shape[0] -10), cv2.FONT_HERSHEY_TRIPLEX, 0.5,  (0,0,0), 1)


    cv2.imshow('img', img)
    
    k = cv2.waitKey(30) & 0xff
    if k==27:
        break
cap.release()
# Out:
# [[277 169 248 248]]
# Number of faces detected:
# ()
# Number of faces detected:
# ()
# Number of faces detected:
# ()
# Number of faces detected:
# [[351 176 217 217]]
# Number of faces detected:
# [[325 168 220 220]]
# Number of faces detected:
# [[325 171 215 215]]
# Number of faces detected:
# [[324 171 219 219]]
# Number of faces detected:
# [[324 171 226 226]]
# Number of faces detected:
# [[317 170 223 223]]
# Number of faces detected:
# [[309 172 220 220]]
# Number of faces detected:
# [[308 164 221 221]]
# Number of faces detected:
# [[298 159 231 231]]
# Number of faces detected:
# [[307 164 222 222]]
# Number of faces detected:
# [[300 161 232 232]]
# Number of faces detected:
# [[306 164 232 232]]
# Number of faces detected:
# [[298 163 233 233]]
# Number of faces detected:
# [[284 152 238 238]]
# Number of faces detected:
# [[272 158 241 241]]
# Number of faces detected:
# [[274 157 234 234]]
# Number of faces detected:
# [[260 158 243 243]]
# Number of faces detected:
# ...

# %%
# cap = cv2.VideoCapture(0)
# while True:
#     _, img = cap.read()
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     faces = face_cascade.detectMultiScale(gray, 1.1, 4)
#     for (x, y, w , h) in faces:
#         cv2.rectangle(img, (x,y), (x+w, y+h), (255, 0 , 0), 2)


#     cv2.imshow('img', img)
    
#     k = cv2.waitKey(30) & 0xff
#     if k==27:
#         break

# cap.release()

# %%
# print(type(image))
 
# if len(image) == 0:
#     print ("No faces found")
 
# else:
#     print (image)
#     #print (faces.shape)
#     print ("Number of faces detected: " + str(cap.shape[0]))
 
#     for (x,y,w,h) in cap:
#         cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),1)
 
#     cv2.rectangle(image, ((0,image.shape[0] -25)),(270, image.shape[0]), (255,255,255), -1)
#     cv2.putText(image, "Number of faces detected: " + str(faces.shape[0]), (0,image.shape[0] -10), cv2.FONT_HERSHEY_TRIPLEX, 0.5,  (0,0,0), 1)
 
#     cv2.imshow('Image with faces',image)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
